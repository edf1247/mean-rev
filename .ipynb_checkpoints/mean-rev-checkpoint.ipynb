# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
df = yf.download("BTC-USD", period="2y")
df.columns = df.columns.droplevel(1)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2024-05-17  67051.875000  67459.460938  65119.316406  65231.296875
# 2024-05-18  66940.804688  67387.328125  66663.500000  67066.210938
# 2024-05-19  66278.367188  67694.296875  65937.179688  66937.929688
# 2024-05-20  71448.195312  71483.562500  66086.171875  66278.742188
# 2024-05-21  70136.531250  71946.460938  69191.125000  71443.062500
#
# Price            Volume
# Date
# 2024-05-17  28031279310
# 2024-05-18  16712277406
# 2024-05-19  19249094538
# 2024-05-20  43850655717
# 2024-05-21  46932005990

# %%
df['close_log_return'] = np.log(df["Close"]/df["Close"].shift())

# %%
df['close_log_return'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["close_log_return_lag1"] = df["close_log_return"].shift()
df.head()
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2024-05-17  67051.875000  67459.460938  65119.316406  65231.296875
# 2024-05-18  66940.804688  67387.328125  66663.500000  67066.210938
# 2024-05-19  66278.367188  67694.296875  65937.179688  66937.929688
# 2024-05-20  71448.195312  71483.562500  66086.171875  66278.742188
# 2024-05-21  70136.531250  71946.460938  69191.125000  71443.062500
#
# Price            Volume  close_log_return  close_log_return_lag1
# Date
# 2024-05-17  28031279310               NaN                    NaN
# 2024-05-18  16712277406         -0.001658                    NaN
# 2024-05-19  19249094538         -0.009945              -0.001658
# 2024-05-20  43850655717          0.075109              -0.009945
# 2024-05-21  46932005990         -0.018529               0.075109

# %%
df["close_log_return_dir_lag1"] = df["close_log_return_lag1"].map(lambda x: 1 if x > 0 else -1)

# %%
df.head()
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2024-05-17  67051.875000  67459.460938  65119.316406  65231.296875
# 2024-05-18  66940.804688  67387.328125  66663.500000  67066.210938
# 2024-05-19  66278.367188  67694.296875  65937.179688  66937.929688
# 2024-05-20  71448.195312  71483.562500  66086.171875  66278.742188
# 2024-05-21  70136.531250  71946.460938  69191.125000  71443.062500
#
# Price            Volume  close_log_return  close_log_return_lag1  \
# Date
# 2024-05-17  28031279310               NaN                    NaN
# 2024-05-18  16712277406         -0.001658                    NaN
# 2024-05-19  19249094538         -0.009945              -0.001658
# 2024-05-20  43850655717          0.075109              -0.009945
# 2024-05-21  46932005990         -0.018529               0.075109
#
# Price       close_log_return_dir_lag1
# Date
# 2024-05-17                         -1
# 2024-05-18                         -1
# ...

# %%
df.groupby('close_log_return_dir_lag1').agg({"close_log_return": ["sum", "mean", "count"]})
# Out:
# Price                     close_log_return
#                                        sum      mean count
# close_log_return_dir_lag1
# -1                                0.100753  0.000276   365
#  1                                0.049912  0.000137   364

# %%
i = int(len(df) * 0.75)
in_sample, out_sample = df.iloc[:i], df.iloc[i:]

# %%
in_sample.head()
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2024-05-17  67051.875000  67459.460938  65119.316406  65231.296875
# 2024-05-18  66940.804688  67387.328125  66663.500000  67066.210938
# 2024-05-19  66278.367188  67694.296875  65937.179688  66937.929688
# 2024-05-20  71448.195312  71483.562500  66086.171875  66278.742188
# 2024-05-21  70136.531250  71946.460938  69191.125000  71443.062500
#
# Price            Volume  close_log_return  close_log_return_lag1  \
# Date
# 2024-05-17  28031279310               NaN                    NaN
# 2024-05-18  16712277406         -0.001658                    NaN
# 2024-05-19  19249094538         -0.009945              -0.001658
# 2024-05-20  43850655717          0.075109              -0.009945
# 2024-05-21  46932005990         -0.018529               0.075109
#
# Price       close_log_return_dir_lag1
# Date
# 2024-05-17                         -1
# 2024-05-18                         -1
# ...

# %%
out_sample.head()
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2025-11-15  95549.148438  96728.468750  94420.468750  94420.468750
# 2025-11-16  94177.078125  96564.187500  92971.164062  95556.867188
# 2025-11-17  92093.875000  95928.367188  91214.757812  94180.875000
# 2025-11-18  92948.875000  93745.078125  89300.460938  92094.531250
# 2025-11-19  91465.992188  92946.164062  88526.828125  92946.164062
#
# Price             Volume  close_log_return  close_log_return_lag1  \
# Date
# 2025-11-15   38500716654          0.012123              -0.054623
# 2025-11-16   71086235862         -0.014464               0.012123
# 2025-11-17   94186165724         -0.022368              -0.014464
# 2025-11-18  101333569062          0.009241              -0.022368
# 2025-11-19   80350354656         -0.016082               0.009241
#
# Price       close_log_return_dir_lag1
# Date
# 2025-11-15                         -1
# 2025-11-16                          1
# ...

# %%
in_sample.groupby('close_log_return_dir_lag1').agg({"close_log_return": ["sum", "mean", "count"]})
# Out:
# Price                     close_log_return
#                                        sum      mean count
# close_log_return_dir_lag1
# -1                                0.237684  0.000877   271
#  1                                0.104367  0.000380   275

# %%
out_sample.groupby('close_log_return_dir_lag1').agg({"close_log_return": ["sum", "mean", "count"]})
# Out:
# Price                     close_log_return
#                                        sum      mean count
# close_log_return_dir_lag1
# -1                               -0.136932 -0.001457    94
#  1                               -0.054454 -0.000612    89

# %%
df["signal"] = -1 * df["close_log_return_dir_lag1"]

# %%
df["trade_log_return"] = df["signal"] * df["close_log_return"]

# %%
df.head()
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2024-05-17  67051.875000  67459.460938  65119.316406  65231.296875
# 2024-05-18  66940.804688  67387.328125  66663.500000  67066.210938
# 2024-05-19  66278.367188  67694.296875  65937.179688  66937.929688
# 2024-05-20  71448.195312  71483.562500  66086.171875  66278.742188
# 2024-05-21  70136.531250  71946.460938  69191.125000  71443.062500
#
# Price            Volume  close_log_return  close_log_return_lag1  \
# Date
# 2024-05-17  28031279310               NaN                    NaN
# 2024-05-18  16712277406         -0.001658                    NaN
# 2024-05-19  19249094538         -0.009945              -0.001658
# 2024-05-20  43850655717          0.075109              -0.009945
# 2024-05-21  46932005990         -0.018529               0.075109
#
# Price       close_log_return_dir_lag1  signal  trade_log_return
# Date
# 2024-05-17                         -1       1               NaN
# ...

# %%
df["cum_trade_log_ret"] = df["trade_log_return"].cumsum()

# %%
df["cum_trade_log_ret"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["is_won"] = df["trade_log_return"] > 0

# %%
df.head()
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2024-05-17  67051.875000  67459.460938  65119.316406  65231.296875
# 2024-05-18  66940.804688  67387.328125  66663.500000  67066.210938
# 2024-05-19  66278.367188  67694.296875  65937.179688  66937.929688
# 2024-05-20  71448.195312  71483.562500  66086.171875  66278.742188
# 2024-05-21  70136.531250  71946.460938  69191.125000  71443.062500
#
# Price            Volume  close_log_return  close_log_return_lag1  \
# Date
# 2024-05-17  28031279310               NaN                    NaN
# 2024-05-18  16712277406         -0.001658                    NaN
# 2024-05-19  19249094538         -0.009945              -0.001658
# 2024-05-20  43850655717          0.075109              -0.009945
# 2024-05-21  46932005990         -0.018529               0.075109
#
# Price       close_log_return_dir_lag1  signal  trade_log_return  \
# Date
# 2024-05-17                         -1       1               NaN
# ...

# %%
df["is_won"].mean()
# Out:
# np.float64(0.4986301369863014)

# %%
r = np.exp(df["trade_log_return"].sum()) - 1

# %%
r
# Out:
# np.float64(0.05215525702095447)

# %% [markdown]
# ## With Z Score

# %%
window = 10

# %%
df["rolling_mean"] = df["close_log_return"].rolling(window).mean()
df["rolling_std"] = df["close_log_return"].rolling(window).std()

# %%
df
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2024-05-17  67051.875000  67459.460938  65119.316406  65231.296875
# 2024-05-18  66940.804688  67387.328125  66663.500000  67066.210938
# 2024-05-19  66278.367188  67694.296875  65937.179688  66937.929688
# 2024-05-20  71448.195312  71483.562500  66086.171875  66278.742188
# 2024-05-21  70136.531250  71946.460938  69191.125000  71443.062500
# ...                  ...           ...           ...           ...
# 2026-05-12  80477.492188  81753.031250  79832.101562  81725.351562
# 2026-05-13  79277.117188  81276.671875  78725.507812  80476.789062
# 2026-05-14  81051.250000  82005.960938  78909.679688  79276.945312
# 2026-05-15  79065.679688  81634.843750  78635.367188  81046.867188
# 2026-05-17  77955.000000  78186.257812  77712.062500  78116.031250
#
# Price            Volume  close_log_return  close_log_return_lag1  \
# Date
# 2024-05-17  28031279310               NaN                    NaN
# ...

# %%
df["zscore"] = (df["close_log_return"] - df["rolling_mean"]) / df["rolling_std"]

# %%
df["zscore"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["zscore_lag1"] = df["zscore"].shift()

# %%
threshold = 1.75
df["signal"] = df["zscore_lag1"].map(lambda x: -1 if x > threshold else (1 if x < -threshold else 0))

# %%
df["z_trade_log_return"] = df["signal"] * df["close_log_return"]

# %%
df["z_cum_trade_log_return"] = df["z_trade_log_return"].cumsum()

# %%
df["z_cum_trade_log_return"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["bh_cum_return"] = df["close_log_return"].cumsum()

# %%
df[["z_cum_trade_log_return", "bh_cum_return"]].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
z_r = np.exp(df["z_trade_log_return"].sum()) - 1
bh_r = np.exp(df["close_log_return"].sum()) - 1

# %%
z_r
# Out:
# np.float64(0.37059400552569666)

# %%
bh_r
# Out:
# np.float64(0.16260730963899128)

# %%
df["z_trade_log_return"].mean() / df["z_trade_log_return"].std() * np.sqrt(365)
# Out:
# np.float64(1.034522565789126)
